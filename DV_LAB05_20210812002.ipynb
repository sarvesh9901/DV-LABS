# %% [markdown]
# # **Sarvesh Karanjkar (20210812002)**
# # **DV LAB 05**

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-1f2c7493-7a51-477a-b5ad-3e797b3d514a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f2c7493-7a51-477a-b5ad-3e797b3d514a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("nc.csv")
df
# Out:
#      fage  mage       mature  weeks     premie  visits      marital  gained  \
# 0     NaN    13  younger mom   39.0  full term    10.0      married    38.0
# 1     NaN    14  younger mom   42.0  full term    15.0      married    20.0
# 2    19.0    15  younger mom   37.0  full term    11.0      married    38.0
# 3    21.0    15  younger mom   41.0  full term     6.0      married    34.0
# 4     NaN    15  younger mom   39.0  full term     9.0      married    27.0
# ..    ...   ...          ...    ...        ...     ...          ...     ...
# 995  47.0    42   mature mom   40.0  full term    10.0  not married    26.0
# 996  34.0    42   mature mom   38.0  full term    18.0  not married    20.0
# 997  39.0    45   mature mom   40.0  full term    15.0  not married    32.0
# 998  55.0    46   mature mom   31.0     premie     8.0  not married    25.0
# 999  45.0    50   mature mom   39.0  full term    14.0  not married    23.0
#
#      weight lowbirthweight  gender      habit   whitemom
# ...

# %%
x= df["weeks"]
y  = df["gained"]
plt.plot(x,y)
plt.xlabel("Weeks")
plt.ylabel('Gained')
plt.title("The amount of weight a mother gained during pregnancy")
plt.show()

# %%
'''week_data = df["weeks"]
plt.hist(week_data , bins=20,edgecolor = 'k')
plt.xlabel("weeks")
plt.ylabel("Frequency")
plt.title("Histogram of Gestation")
plt.show()'''
sns.histplot(data = df, x= "weeks" )
# Out:
# <Axes: xlabel='weeks', ylabel='Count'>

# %%
birth_wght = df["lowbirthweight"]
plt.hist(birth_wght , bins=20,edgecolor = 'k')
plt.xlabel("Birth Weight")
plt.ylabel("Frequency")
plt.title("Histogram of Birthweight of Newborns")
plt.show()

# %%
sns.boxplot(data=df, x="weeks", y="habit")
# Out:
# <Axes: xlabel='weeks', ylabel='habit'>

# %%
agediff = df['mage'] - df['fage']
plt.hist(agediff, bins=20,edgecolor='k')
plt.xlabel("Age Diffrence")
plt.ylabel('Frequency')
plt.title("Distribution of Age Between Mother and Father")
plt.show()
df['age_diff'] = df['mage'] - df['fage']
# method 02
sns.histplot(data = df,x='age_diff')
# Out:
# <Axes: xlabel='age_diff', ylabel='Count'>
